# %% [markdown]
# # Functions & tools

# %%
# Enterprise Function Definitions with Mock Data

def get_employee_profile(employee_id: str):
    """Returns employee profile information including personal details and performance metrics.
    
    Required parameters:
    - employee_id: str - Unique identifier for the employee
    """
    employee_data = {
        "EMP001": {
            "name": "John Smith",
            "department": "Engineering",
            "position": "Senior Developer",
            "hire_date": "2020-03-15",
            "performance_rating": 4.2,
            "status": "Active"
        },
        "EMP002": {
            "name": "Sarah Johnson",
            "department": "Marketing",
            "position": "Marketing Manager",
            "hire_date": "2019-08-22",
            "performance_rating": 4.5,
            "status": "Active"
        }
    }
    return employee_data.get(employee_id, {
        "error": "Employee not found",
        "status": "Not Found"
    })

def create_sales_opportunity(customer_id: str, opportunity_name: str, estimated_value: float, probability: int, expected_close_date: str = None):
    """Create a new sales opportunity with lead information and initial assessment.
    
    Required parameters:
    - customer_id: str - Associated customer ID
    - opportunity_name: str - Name/title of the sales opportunity
    - estimated_value: float - Estimated deal value in USD
    - probability: int - Probability of closing the deal (0-100%)
    
    Optional parameters:
    - expected_close_date: str - Expected date to close the deal (YYYY-MM-DD)
    """
    opportunity_id = f"OPP_{customer_id}_{len(opportunity_name)}"
    
    return {
        "success": True,
        "opportunity_id": opportunity_id,
        "message": f"Sales opportunity '{opportunity_name}' created successfully",
        "customer_id": customer_id,
        "estimated_value": estimated_value,
        "probability": probability,
        "status": "Created"
    }

def update_inventory_count(product_id: str, quantity_change: int, reason: str, updated_by: str):
    """Update product inventory quantity with tracking information.
    
    Required parameters:
    - product_id: str - Product identifier
    - quantity_change: int - Quantity delta (positive/negative)
    - reason: str - Change reason (sale, purchase, return, damage, adjustment)
    - updated_by: str - Employee ID performing update
    """
    current_inventory = {
        "PROD001": 150,
        "PROD002": 75,
        "PROD003": 200
    }
    
    current_qty = current_inventory.get(product_id, 100)
    new_qty = current_qty + quantity_change
    
    return {
        "success": True,
        "product_id": product_id,
        "previous_quantity": current_qty,
        "quantity_change": quantity_change,
        "new_quantity": new_qty,
        "reason": reason,
        "updated_by": updated_by,
        "timestamp": "2025-09-13T10:30:00Z",
        "message": f"Inventory updated successfully for {product_id}"
    }

def process_invoice_payment(invoice_id: str, vendor_id: str, amount: float, currency: str = "USD", payment_method: str = "ACH"):
    """Process an invoice payment with vendor and amount details.
    
    Required parameters:
    - invoice_id: str - Invoice ID
    - vendor_id: str - Vendor ID
    - amount: float - Payment amount
    
    Optional parameters:
    - currency: str - Currency code (USD, EUR, GBP) - default: USD
    - payment_method: str - Payment method (ACH, Wire, Check) - default: ACH
    """
    transaction_id = f"TXN_{invoice_id}_{vendor_id}"
    
    return {
        "success": True,
        "transaction_id": transaction_id,
        "invoice_id": invoice_id,
        "vendor_id": vendor_id,
        "amount": amount,
        "currency": currency,
        "payment_method": payment_method,
        "status": "Processed",
        "processing_date": "2025-09-13",
        "message": f"Payment of {amount} {currency} processed successfully"
    }

def create_helpdesk_ticket(user_id: str, issue_summary: str, category: str, description: str, priority: str = "medium", attachments: list = None):
    """Create an IT support ticket for user issues.
    
    Required parameters:
    - user_id: str - Employee ID
    - issue_summary: str - Brief issue summary
    - category: str - Issue category (hardware, software, network, security, email, phone, printer, access)
    - description: str - Detailed problem description
    
    Optional parameters:
    - priority: str - Priority level (low, medium, high, critical) - default: medium
    - attachments: list - Attached files information
    """
    ticket_id = f"TICKET_{user_id}_{category.upper()}_{len(issue_summary)}"
    
    return {
        "success": True,
        "ticket_id": ticket_id,
        "user_id": user_id,
        "issue_summary": issue_summary,
        "category": category,
        "priority": priority,
        "status": "Open",
        "created_date": "2025-09-13T10:30:00Z",
        "estimated_resolution": "2025-09-15T10:30:00Z",
        "message": f"Support ticket {ticket_id} created successfully"
    }

def approve_procurement_request(request_id: str, approver_id: str, status: str, comments: str = None, budget_check: bool = True):
    """Approve or reject a procurement request with optional comments.
    
    Required parameters:
    - request_id: str - ID of the procurement request
    - approver_id: str - ID of the approving manager
    - status: str - Approval status (Approved, Rejected, Pending)
    
    Optional parameters:
    - comments: str - Optional comments for approval/rejection
    - budget_check: bool - Whether to enforce budget validation - default: True
    """
    return {
        "success": True,
        "request_id": request_id,
        "approver_id": approver_id,
        "status": status,
        "comments": comments or "No additional comments",
        "budget_check_passed": budget_check,
        "approval_date": "2025-09-13T10:30:00Z",
        "message": f"Procurement request {request_id} has been {status.lower()}"
    }

def create_sales_proposal(client_id: str, proposal_title: str, products: list, payment_terms: dict = None):
    """Generate a sales proposal for a client with products and terms.
    
    Required parameters:
    - client_id: str - Client ID
    - proposal_title: str - Proposal title
    - products: list - List of products with product_id, quantity, unit_price
    
    Optional parameters:
    - payment_terms: dict - Payment terms with due_in_days
    """
    proposal_id = f"PROP_{client_id}_{len(proposal_title)}"
    total_value = sum(p['quantity'] * p['unit_price'] for p in products)
    
    return {
        "success": True,
        "proposal_id": proposal_id,
        "client_id": client_id,
        "proposal_title": proposal_title,
        "total_value": total_value,
        "product_count": len(products),
        "payment_terms": payment_terms or {"due_in_days": 30},
        "created_date": "2025-09-13",
        "status": "Draft",
        "message": f"Sales proposal {proposal_id} created with total value ${total_value}"
    }

def conduct_compliance_audit(audit_id: str, regulatory_frameworks: list, business_units: list, audit_period: dict, lead_auditor: str, risk_categories: list, materiality_threshold: float = None, automated_testing: bool = True):
    """Execute a compliance audit with risk assessment and reporting.
    
    Required parameters:
    - audit_id: str - Unique identifier for the audit
    - regulatory_frameworks: list - Frameworks to audit against (GDPR, HIPAA, SOX, etc.)
    - business_units: list - Business units to include
    - audit_period: dict - Start and end dates for audit period
    - lead_auditor: str - Employee ID of lead auditor
    - risk_categories: list - Risk categories to evaluate
    
    Optional parameters:
    - materiality_threshold: float - Financial materiality threshold
    - automated_testing: bool - Enable automated testing - default: True
    """
    return {
        "success": True,
        "audit_id": audit_id,
        "frameworks_count": len(regulatory_frameworks),
        "business_units_count": len(business_units),
        "lead_auditor": lead_auditor,
        "risk_categories": risk_categories,
        "audit_period": audit_period,
        "automated_testing": automated_testing,
        "status": "Initiated",
        "estimated_completion": "2025-10-13",
        "message": f"Compliance audit {audit_id} initiated successfully"
    }

def book_meeting_room(room_id: str, date: str, start_time: str, end_time: str, attendee_count: int, meeting_title: str, organizer_id: str, equipment_needed: list = None):
    """Reserve a meeting room for a specific date and time.
    
    Required parameters:
    - room_id: str - Unique meeting room ID (e.g., 'CONF-A-301')
    - date: str - Booking date (YYYY-MM-DD)
    - start_time: str - Start time (HH:MM, 24-hour)
    - end_time: str - End time (HH:MM, 24-hour)
    - attendee_count: int - Number of attendees (1-100)
    - meeting_title: str - Title of the meeting
    - organizer_id: str - Employee ID of the organizer
    
    Optional parameters:
    - equipment_needed: list - Equipment required (e.g., ['projector', 'whiteboard'])
    """
    booking_id = f"BOOK_{room_id}_{date}_{start_time.replace(':', '')}"
    
    return {
        "success": True,
        "booking_id": booking_id,
        "room_id": room_id,
        "date": date,
        "start_time": start_time,
        "end_time": end_time,
        "attendee_count": attendee_count,
        "meeting_title": meeting_title,
        "organizer_id": organizer_id,
        "equipment_needed": equipment_needed or [],
        "status": "Confirmed",
        "message": f"Meeting room {room_id} booked successfully for {date}"
    }

def track_shipment(tracking_number: str, carrier: str, include_history: bool = False):
    """Track the current status and location of a shipment.
    
    Required parameters:
    - tracking_number: str - The unique tracking identifier
    - carrier: str - Shipping carrier (FedEx, UPS, DHL, USPS, Amazon Logistics)
    
    Optional parameters:
    - include_history: bool - Whether to include full tracking history - default: False
    """
    tracking_data = {
        "tracking_number": tracking_number,
        "carrier": carrier,
        "status": "In Transit",
        "current_location": "Distribution Center - Chicago, IL",
        "estimated_delivery": "2025-09-15",
        "last_updated": "2025-09-13T08:45:00Z"
    }
    
    if include_history:
        tracking_data["history"] = [
            {"date": "2025-09-12", "location": "Origin Facility", "status": "Picked Up"},
            {"date": "2025-09-13", "location": "Chicago, IL", "status": "In Transit"}
        ]
    
    return {
        "success": True,
        "tracking_info": tracking_data,
        "message": f"Shipment {tracking_number} is currently in transit"
    }

def escalate_support_ticket(ticket_id: str, reason: str, target_team: str, notify_customer: bool = True):
    """Escalate a support ticket to a higher-priority team.
    
    Required parameters:
    - ticket_id: str - Support ticket ID
    - reason: str - Reason for escalation
    - target_team: str - Team to escalate to (senior_support, engineering, billing)
    
    Optional parameters:
    - notify_customer: bool - Notify customer about escalation - default: True
    """
    return {
        "success": True,
        "ticket_id": ticket_id,
        "reason": reason,
        "target_team": target_team,
        "escalated_at": "2025-09-13T10:30:00Z",
        "customer_notified": notify_customer,
        "new_priority": "High",
        "estimated_response": "2025-09-13T14:00:00Z",
        "message": f"Ticket {ticket_id} escalated to {target_team} team"
    }

def create_performance_review(employee_id: str, reviewer_id: str, review_period: dict, overall_rating: int, review_type: str = "annual"):
    """Create a performance review for an employee.
    
    Required parameters:
    - employee_id: str - ID of the employee being reviewed
    - reviewer_id: str - ID of the reviewer (manager/supervisor)
    - review_period: dict - Start and end dates for review period
    - overall_rating: int - Performance rating (1-5 scale)
    
    Optional parameters:
    - review_type: str - Type of review (annual, mid_year, quarterly, probationary) - default: annual
    """
    review_id = f"REV_{employee_id}_{review_type}_{overall_rating}"
    
    return {
        "success": True,
        "review_id": review_id,
        "employee_id": employee_id,
        "reviewer_id": reviewer_id,
        "review_period": review_period,
        "overall_rating": overall_rating,
        "review_type": review_type,
        "status": "Draft",
        "created_date": "2025-09-13",
        "message": f"Performance review {review_id} created with rating {overall_rating}/5"
    }

def schedule_meeting(title: str, start_time: str, end_time: str, participants: list, agenda: str = None, video_call_link: str = None):
    """Schedule a meeting with participants and basic details.
    
    Required parameters:
    - title: str - Meeting title
    - start_time: str - Start time (ISO format)
    - end_time: str - End time (ISO format)
    - participants: list - List of participants with email and role
    
    Optional parameters:
    - agenda: str - Brief agenda
    - video_call_link: str - URL for virtual meeting
    """
    meeting_id = f"MEET_{len(title)}_{len(participants)}"
    
    return {
        "success": True,
        "meeting_id": meeting_id,
        "title": title,
        "start_time": start_time,
        "end_time": end_time,
        "participant_count": len(participants),
        "agenda": agenda or "Agenda to be provided",
        "video_call_link": video_call_link,
        "status": "Scheduled",
        "message": f"Meeting '{title}' scheduled successfully with {len(participants)} participants"
    }

def track_ad_performance(ad_ids: list, platform: str, metrics: list, polling_interval_minutes: int = None):
    """Monitor real-time performance metrics for paid ads across platforms.
    
    Required parameters:
    - ad_ids: list - List of ad IDs to track
    - platform: str - Advertising platform (google_ads, facebook_ads, linkedin_ads)
    - metrics: list - Metrics to fetch (impressions, clicks, cost_per_click, conversion_rate)
    
    Optional parameters:
    - polling_interval_minutes: int - How often to refresh data
    """
    performance_data = {}
    for ad_id in ad_ids:
        performance_data[ad_id] = {
            "impressions": 15420,
            "clicks": 892,
            "cost_per_click": 2.35,
            "conversion_rate": 3.2
        }
    
    return {
        "success": True,
        "platform": platform,
        "ads_tracked": len(ad_ids),
        "metrics_requested": metrics,
        "polling_interval": polling_interval_minutes or 60,
        "performance_data": performance_data,
        "last_updated": "2025-09-13T10:30:00Z",
        "message": f"Tracking {len(ad_ids)} ads on {platform}"
    }

def send_offer_letter(candidate_id: str, job_title: str, salary_base: float, start_date: str, expiration_days: int = 7):
    """Send a job offer letter to a candidate.
    
    Required parameters:
    - candidate_id: str - Candidate's unique ID
    - job_title: str - Job title for the offer
    - salary_base: float - Base salary amount
    - start_date: str - Start date (YYYY-MM-DD)
    
    Optional parameters:
    - expiration_days: int - Days before offer expires - default: 7
    """
    offer_id = f"OFFER_{candidate_id}_{job_title.replace(' ', '_')}"
    
    return {
        "success": True,
        "offer_id": offer_id,
        "candidate_id": candidate_id,
        "job_title": job_title,
        "salary_base": salary_base,
        "start_date": start_date,
        "expiration_date": "2025-09-20",  # start_date + expiration_days
        "status": "Sent",
        "sent_date": "2025-09-13",
        "message": f"Offer letter sent to candidate {candidate_id} for {job_title} position"
    }

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_employee_profile",
            "description": "Retrieve complete employee profile information including personal details, employment history, and performance metrics.",
            "parameters": {
                "type": "object",
                "properties": {
                    "employee_id": {
                        "type": "string",
                        "description": "Unique identifier for the employee"
                    }
                },
                "required": [
                    "employee_id"
                ]
            }        
        }
    },
    {
        "type": "function",
        "function": {
            "name": "create_sales_opportunity",
            "description": "Create a new sales opportunity with lead information and initial assessment.",
            "parameters": {
                "type": "object",
                "properties": {
                    "customer_id": {
                        "type": "string",
                        "description": "Associated customer ID"
                    },
                    "opportunity_name": {
                        "type": "string",
                        "description": "Name/title of the sales opportunity"
                    },
                    "estimated_value": {
                        "type": "number",
                        "description": "Estimated deal value in USD"
                    },
                    "probability": {
                        "type": "number",
                        "minimum": 0,
                        "maximum": 100,
                        "description": "Probability of closing the deal (0-100%)"
                    },
                    "expected_close_date": {
                        "type": "string",
                        "format": "date",
                        "description": "Expected date to close the deal"
                    }
                },
                "required": [
                    "customer_id",
                    "opportunity_name",
                    "estimated_value",
                    "probability"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "update_inventory_count",
            "description": "Update product inventory quantity",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_id": {
                        "type": "string",
                        "description": "Product identifier"
                    },
                    "quantity_change": {
                        "type": "integer",
                        "description": "Quantity delta (positive/negative)"
                    },
                    "reason": {
                        "type": "string",
                        "enum": [
                            "sale",
                            "purchase",
                            "return",
                            "damage",
                            "adjustment"
                        ],
                        "description": "Change reason"
                    },
                    "updated_by": {
                        "type": "string",
                        "description": "Employee ID performing update"
                    }
                },
                "required": [
                    "product_id",
                    "quantity_change",
                    "reason",
                    "updated_by"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "process_invoice_payment",
            "description": "Process an invoice payment.",
            "parameters": {
                "type": "object",
                "properties": {
                    "invoice_id": {
                        "type": "string",
                        "description": "Invoice ID."
                    },
                    "vendor_id": {
                        "type": "string",
                        "description": "Vendor ID."
                    },
                    "amount": {
                        "type": "number",
                        "description": "Payment amount."
                    },
                    "currency": {
                        "type": "string",
                        "enum": ["USD", "EUR", "GBP"],
                        "default": "USD"
                    },
                    "payment_method": {
                        "type": "string",
                        "enum": ["ACH", "Wire", "Check"],
                        "default": "ACH"
                    }
                },
                "required": ["invoice_id", "vendor_id", "amount"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "create_helpdesk_ticket",
            "description": "Create an IT support ticket.",
            "parameters": {
                "type": "object",
                "properties": {
                    "user_id": {
                        "type": "string",
                        "description": "Employee ID"
                    },
                    "issue_summary": {
                        "type": "string",
                        "description": "Brief issue summary"
                    },
                    "category": {
                        "type": "string",
                        "enum": [
                            "hardware",
                            "software",
                            "network",
                            "security",
                            "email",
                            "phone",
                            "printer",
                            "access"
                        ],
                        "description": "Issue category"
                    },
                    "priority": {
                        "type": "string",
                        "enum": [
                            "low",
                            "medium",
                            "high",
                            "critical"
                        ],
                        "description": "Priority level"
                    },
                    "description": {
                        "type": "string",
                        "description": "Detailed problem description"
                    },
                    "attachments": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "filename": {
                                    "type": "string",
                                    "description": "Attachment filename"
                                },
                                "file_type": {
                                    "type": "string",
                                    "description": "File type (e.g., image, log)"
                                }
                            }
                        },
                        "description": "Attached files"
                    }
                },
                "required": [
                    "user_id",
                    "issue_summary",
                    "category",
                    "description"         
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "approve_procurement_request",
            "description": "Approve/reject a procurement request with optional comments.",
            "parameters": {
                "type": "object",
                "properties": {
                    "request_id": {
                        "type": "string",
                        "description": "ID of the procurement request."
                    },
                    "approver_id": {
                        "type": "string",
                        "description": "ID of the approving manager."
                    },
                    "status": {
                        "type": "string",
                        "enum": [
                            "Approved",
                            "Rejected",
                            "Pending"
                        ],
                        "description": "Approval status."
                    },
                    "comments": {
                        "type": "string",
                        "description": "Optional comments for approval/rejection."
                    },
                    "budget_check": {
                        "type": "boolean",
                        "description": "Whether to enforce budget validation (default: true).",
                        "default": True
                    }
                },
                "required": [
                    "request_id",
                    "approver_id",
                    "status"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "create_sales_proposal",
            "description": "Generate a sales proposal for a client.",
            "parameters": {
                "type": "object",
                "properties": {
                    "client_id": {
                        "type": "string",
                        "description": "Client ID."
                    },
                    "proposal_title": {
                        "type": "string",
                        "description": "Proposal title."
                    },
                    "products": {
                        "type": "array",
                        "description": "Products/services in proposal.",
                        "items": {
                            "type": "object",
                            "properties": {
                                "product_id": {
                                    "type": "string",
                                    "description": "Product ID."
                                },
                                "quantity": {
                                    "type": "integer",
                                    "description": "Quantity."
                                },
                                "unit_price": {
                                    "type": "number",
                                    "description": "Price per unit."
                                }
                            },
                            "required": [
                                "product_id",
                                "quantity",
                                "unit_price"
                            ]
                        }
                    },
                    "payment_terms": {
                        "type": "object",
                        "description": "Payment terms.",
                        "properties": {
                            "due_in_days": {
                                "type": "integer",
                                "description": "Days until payment due."
                            }
                        }
                    }
                },
                "required": [
                    "client_id",
                    "proposal_title",
                    "products"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "conduct_compliance_audit",
            "description": "Execute a compliance audit with risk assessment and reporting.",
            "parameters": {
                "type": "object",
                "properties": {
                    "audit_id": {
                        "type": "string",
                        "description": "Unique identifier for the audit"
                    },
                    "regulatory_frameworks": {
                        "type": "array",
                        "items": {
                            "type": "string",
                            "enum": ["GDPR", "HIPAA", "SOX", "PCI_DSS", "ISO_27001", "CCPA", "SOC2", "FISMA"]
                        },
                        "description": "Frameworks to audit against"
                    },
                    "business_units": {
                        "type": "array",
                        "items": {
                            "type": "string"
                        },
                        "description": "Business units to include"
                    },
                    "audit_period": {
                        "type": "object",
                        "properties": {
                            "start_date": {
                                "type": "string",
                                "description": "Audit start date (YYYY-MM-DD)"
                            },
                            "end_date": {
                                "type": "string",
                                "description": "Audit end date (YYYY-MM-DD)"
                            }
                        },
                        "required": ["start_date", "end_date"]
                    },
                    "lead_auditor": {
                        "type": "string",
                        "description": "Employee ID of lead auditor"
                    },
                    "risk_categories": {
                        "type": "array",
                        "items": {
                            "type": "string",
                            "enum": ["data_privacy", "financial_reporting", "operational", "security", "environmental", "employment"]
                        },
                        "description": "Risk categories to evaluate"
                    },
                    "materiality_threshold": {
                        "type": "number",
                        "description": "Financial materiality threshold"
                    },
                    "automated_testing": {
                        "type": "boolean",
                        "default": True,
                        "description": "Enable automated testing"
                    }
                },
                "required": ["audit_id", "regulatory_frameworks", "business_units", "audit_period", "lead_auditor", "risk_categories"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "book_meeting_room",
            "description": "Reserve a meeting room for a specific date and time.",
            "parameters": {
                "type": "object",
                "properties": {
                    "room_id": {
                        "type": "string",
                        "description": "Unique meeting room ID (e.g., 'CONF-A-301')"
                    },
                    "date": {
                        "type": "string",
                        "description": "Booking date (YYYY-MM-DD)"
                    },
                    "start_time": {
                        "type": "string",
                        "description": "Start time (HH:MM, 24-hour)"
                    },
                    "end_time": {
                        "type": "string",
                        "description": "End time (HH:MM, 24-hour)"
                    },
                    "attendee_count": {
                        "type": "integer",
                        "description": "Number of attendees (1-100)",
                        "minimum": 1,
                        "maximum": 100
                    },
                    "meeting_title": {
                        "type": "string",
                        "description": "Title of the meeting"
                    },
                    "organizer_id": {
                        "type": "string",
                        "description": "Employee ID of the organizer"
                    },
                    "equipment_needed": {
                        "type": "array",
                        "items": {
                            "type": "string"
                        },
                        "description": "Equipment required (e.g., 'projector')"
                    }
                },
                "required": [
                    "room_id",
                    "date",
                    "start_time",
                    "end_time",
                    "attendee_count",
                    "meeting_title",
                    "organizer_id"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "track_shipment",
            "description": "Track the current status and location of a shipment using tracking number.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tracking_number": {
                        "type": "string",
                        "description": "The unique tracking identifier for the shipment"
                    },
                    "carrier": {
                        "type": "string",
                        "description": "Shipping carrier name",
                        "enum": [
                            "FedEx",
                            "UPS",
                            "DHL",
                            "USPS",
                            "Amazon Logistics"
                        ]
                    },
                    "include_history": {
                        "type": "boolean",
                        "description": "Whether to include full tracking history",
                        "default": False
                    }
                },
                "required": [
                    "tracking_number",
                    "carrier"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "escalate_support_ticket",
            "description": "Escalate a support ticket to a higher-priority team.",
            "parameters": {
                "type": "object",
                "properties": {
                    "ticket_id": {
                        "type": "string",
                        "description": "Support ticket ID."
                    },
                    "reason": {
                        "type": "string",
                        "description": "Reason for escalation (e.g., 'critical', 'unresolved')."
                    },
                    "target_team": {
                        "type": "string",
                        "enum": [
                            "senior_support",
                            "engineering",
                            "billing"
                        ],
                        "description": "Team to escalate to."
                    },
                    "notify_customer": {
                        "type": "boolean",
                        "default": True,
                        "description": "Notify customer about escalation."
                    }
                },
                "required": [
                    "ticket_id",
                    "reason",
                    "target_team"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "create_performance_review",
            "description": "Create a performance review for an employee.",
            "parameters": {
                "type": "object",
                "properties": {
                    "employee_id": {
                        "type": "string",
                        "description": "ID of the employee being reviewed"
                    },
                    "reviewer_id": {
                        "type": "string",
                        "description": "ID of the reviewer (manager/supervisor)"
                    },
                    "review_period": {
                        "type": "object",
                        "properties": {
                            "start_date": {
                                "type": "string",
                                "description": "Review period start date (YYYY-MM-DD)"
                            },
                            "end_date": {
                                "type": "string",
                                "description": "Review period end date (YYYY-MM-DD)"
                            }
                        },
                        "required": [
                            "start_date",
                            "end_date"
                        ]
                    },
                    "overall_rating": {
                        "type": "integer",
                        "description": "Performance rating (1-5 scale)",
                        "minimum": 1,
                        "maximum": 5
                    },
                    "review_type": {
                        "type": "string",
                        "enum": [
                            "annual",
                            "mid_year",
                            "quarterly",
                            "probationary"
                        ],
                        "description": "Type of review"
                    }
                },
                "required": [
                    "employee_id",
                    "reviewer_id",
                    "review_period",
                    "overall_rating"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "schedule_meeting",
            "description": "Schedule a meeting with participants and basic details.",
            "parameters": {
                "type": "object",
                "properties": {
                    "title": {
                        "type": "string",
                        "description": "Meeting title."
                    },
                    "start_time": {
                        "type": "string",
                        "description": "Start time (ISO format)."
                    },
                    "end_time": {
                        "type": "string",
                        "description": "End time (ISO format)."
                    },
                    "participants": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "email": {
                                    "type": "string",
                                    "description": "Participant's email address."
                                },
                                "role": {
                                    "type": "string",
                                    "enum": [
                                        "required",
                                        "optional"
                                    ]
                                }
                            },
                            "required": [
                                "email"
                            ]
                        }
                    },
                    "agenda": {
                        "type": "string",
                        "description": "Brief agenda (optional)."
                    },
                    "video_call_link": {
                        "type": "string",
                        "description": "URL for virtual meeting (optional)."
                    }
                },
                "required": [
                    "title",
                    "start_time",
                    "end_time",
                    "participants"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "track_ad_performance",
            "description": "Monitor real-time performance metrics for paid ads across platforms.",
            "parameters": {
                "type": "object",
                "properties": {
                    "ad_ids": {
                        "type": "array",
                        "items": {
                            "type": "string"
                        },
                        "description": "List of ad IDs to track."
                    },
                    "platform": {
                        "type": "string",
                        "enum": [
                            "google_ads",
                            "facebook_ads",
                            "linkedin_ads"
                        ],
                        "description": "Advertising platform."
                    },
                    "metrics": {
                        "type": "array",
                        "items": {
                            "type": "string",
                            "enum": [
                                "impressions",
                                "clicks",
                                "cost_per_click",
                                "conversion_rate"
                            ]
                        },
                        "description": "Metrics to fetch."
                    },
                    "polling_interval_minutes": {
                        "type": "integer",
                        "description": "How often to refresh data."
                    }
                },
                "required": [
                    "ad_ids",
                    "platform",
                    "metrics"
                ]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "send_offer_letter",
            "description": "Send a job offer letter to a candidate.",
            "parameters": {
                "type": "object",
                "properties": {
                    "candidate_id": {
                        "type": "string",
                        "description": "Candidate's unique ID."
                    },
                    "job_title": {
                        "type": "string",
                        "description": "Job title for the offer."
                    },
                    "salary_base": {
                        "type": "number",
                        "description": "Base salary amount."
                    },
                    "start_date": {
                        "type": "string",
                        "description": "Start date (YYYY-MM-DD)."
                    },
                    "expiration_days": {
                        "type": "integer",
                        "description": "Days before offer expires."
                    }
                },
                "required": [
                    "candidate_id",
                    "job_title",
                    "salary_base",
                    "start_date"
                ]
            }
        }
    }
]

# %% [markdown]
# # Missing Parameter

# %%
from openai import OpenAI
import json

from tqdm import tqdm
# from secret_key import openai_api_key
import pandas as pd
import datetime

from openai import OpenAI
import json

client = OpenAI(
  base_url = "https://openrouter.ai/api/v1",
  #api_key = " ",
  api_key = " " #my-own-api-key
  
)


# Utils
def call_model(messages):
    """Call the model with the provided messages"""
    system_message = {
        "role": "system",
        "content": """You are an AI assistant with access to a set of tools. Your goal is to accurately and helpfully respond to user queries.
        **Workflow:**
        1. **Understand Query:** Analyze the user's request and their intent.
        2. **Decide Tool Use:**
            * If you can answer directly from your knowledge, do so.
            * If external info/action is needed, use a tool.
        3. **Select & Extract Tool Inputs:** 
            * Choose the best tool from `tools` list.
            * Identify all required parameters from the query. 
            * Use default values from the tool specification for any fields not explicitly mentioned by the user.
            * **Always include default values in the tool call, even if the user did not mention them.**
            * Don't make assumptions beyond what's in the query or default values.
        4. **Execute Tool (Output Format):**
            * **If you have all required parameters (from user input or defaults), immediately make the tool call.**
            * **Do not ask for missing optional parameters - use defaults.**
            * **Only ask for clarification if absolutely required parameters are missing.**
            * **Once you receive the missing required parameters, immediately make the tool call without further questions.**
            """
    }
    try:
        response = client.chat.completions.create(
            model="mistralai/ministral-8b",
            messages=[system_message] + messages,
            tools=tools,
            temperature=0.0,
            parallel_tool_calls=False
        )
        return response
    except Exception as e:
        return {"choices": [{"message": {"content": f"Error calling model: {str(e)}"}}]}

# Process single row conversation
def process_single_row_conversation(queries, row_index):
    """Process a single row's conversation and return the conversation history"""
    conversation = []
    messages = []
    
    for query in queries:
        # Add user message
        print(f"Row {row_index + 1} - User: {query['content']}")
        conversation.append({
            "role": "user",
            "content": query['content']
        })
        messages.append({
            "role": "user",
            "content": query['content']
        })
        
        try:
            # Call model with conversation history
            response = call_model(messages)
            
            # Handle Mistral's response structure
            assistant_message = {
                "role": "assistant",
                "content": response.choices[0].message.content,
                "tool_calls": getattr(response.choices[0].message, 'tool_calls', None)
            }
            
            # Process assistant response
            if assistant_message.get('tool_calls'):
                # Format tool calls
                tool_calls_json = []
                for tool_call in assistant_message['tool_calls']:
                    tool_call_json = {
                        "id": tool_call.id,
                        "type": "function",
                        "function": {
                            "name": tool_call.function.name,
                            "arguments": tool_call.function.arguments
                        }
                    }
                    tool_calls_json.append(tool_call_json)
                
                # Add tool call message to messages (for API)
                messages.append({
                    "role": "assistant",
                    "content": None,
                    "tool_calls": assistant_message['tool_calls']
                })
                
                # Add formatted response to conversation (for display)
                tool_call_content = f"<tool_call>{json.dumps(tool_calls_json, indent=2)}</tool_call>"
                print(f"Row {row_index + 1} - Assistant: {tool_call_content}")
                conversation.append({
                    "role": "assistant",
                    "content": tool_call_content
                })
                
                # Add tool response messages for each tool call
                for tool_call in assistant_message['tool_calls']:
                    # Simulate calling the function (adapt from first code)
                    function_name = tool_call.function.name
                    function_args = json.loads(tool_call.function.arguments)
                    tool_response = call_function_and_get_response(function_name, function_args, tool_call.id)
                    print(f"Row {row_index + 1} - Function Response: {tool_response['content']}")
                    messages.append(tool_response)
                    conversation.append({
                        "role": "tool",
                        "content": tool_response['content'],
                        "tool_call_id": tool_call.id
                    })
                
                # Call model again to get assistant response after tool call
                response = call_model(messages)
                assistant_message = {
                    "role": "assistant",
                    "content": response.choices[0].message.content,
                    "tool_calls": getattr(response.choices[0].message, 'tool_calls', None)
                }
                print(f"Row {row_index + 1} - Assistant: {assistant_message['content']}")
                conversation.append({
                    "role": "assistant",
                    "content": assistant_message['content']
                })
                messages.append({
                    "role": "assistant",
                    "content": assistant_message['content']
                })
            
            else:
                # Regular text response
                print(f"Row {row_index + 1} - Assistant: {assistant_message['content']}")
                conversation.append({
                    "role": "assistant",
                    "content": assistant_message['content']
                })
                messages.append({
                    "role": "assistant",
                    "content": assistant_message['content']
                })
            
        except Exception as e:
            print(f"Row {row_index + 1} - Assistant: Error processing message: {str(e)}")
            conversation.append({
                "role": "assistant",
                "content": f"Error: {str(e)}"
            })
    
    return conversation

def call_function_and_get_response(function_name, function_arguments):
    """Execute the function and return its response as a tool message"""
    try:
        # Parse the JSON string into a dictionary
        if isinstance(function_arguments, str):
            args = json.loads(function_arguments)
        else:
            args = function_arguments
            
        function_response = globals()[function_name](**args)
        return {
            "role": "tool",
            "content": json.dumps(function_response),
            "tool_call_id": f"call_{function_name}_{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
        }
    except Exception as e:
        return {
            "role": "tool",
            "content": json.dumps({"error": f"Function {function_name} failed: {str(e)}"}),
            "tool_call_id": f"error_{function_name}_{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
        }

# Main execution
def execute_multi_turn_tool_call(filename):
    """Execute multi-turn tool calls and save each row's conversation separately"""
    try:
        # Load Excel file
        df = pd.read_excel(filename)
        df = df.head(10)  # Process only first 1 rows
        total_rows = len(df)
        print(f"\nFound {total_rows} rows to process (limited to first 1 rows)")
        
        # Prepare output data
        output_data = []
        
        # Process each row with progress bar
        with tqdm(total=total_rows, desc="Processing rows") as pbar:
            for idx, row in df.iterrows():
                try:
                    # Update progress bar description
                    pbar.set_description(f"Processing row {idx + 1}/{total_rows}")
                    
                    # Parse queries from current row
                    queries = json.loads(row['Queries (3 turns in JSON format)'])

                    # Process conversation for this row
                    conversation = process_single_row_conversation(queries, idx)
                    
                    # Store row data
                    row_data = {
                        'Row_Number': idx + 1,
                        'Original_Queries': row['Queries (3 turns in JSON format)'],
                        'Conversation_History': json.dumps(conversation, indent=2),
                        'Total_Messages': len(conversation)
                    }
                    output_data.append(row_data)
                    
                    print(f"Row {idx + 1} completed - {len(conversation)} messages in conversation\n")
                    
                except Exception as e:
                    print(f"\nError processing row {idx + 1}: {e}")
                    # Add error entry
                    error_data = {
                        'Row_Number': idx + 1,
                        'Original_Queries': str(row.get('Queries (2 queries in JSON format)', 'N/A')),
                        'Conversation_History': json.dumps([{"error": f"Failed to process: {str(e)}"}]),
                        'Total_Messages': 0
                    }
                    output_data.append(error_data)
                
                # Update progress bar
                pbar.update(1)
        
        # Save all conversations to Excel
        output_df = pd.DataFrame(output_data)
        
        # Create Excel file with proper formatting
        with pd.ExcelWriter('ministral_miss_para.xlsx', engine='openpyxl') as writer:
            output_df.to_excel(writer, index=False, sheet_name='All_Conversations')
            
            # Format the worksheet
            worksheet = writer.sheets['All_Conversations']
            worksheet.column_dimensions['A'].width = 10  # Row Number
            worksheet.column_dimensions['B'].width = 50  # Original Queries
            worksheet.column_dimensions['C'].width = 100  # Conversation History
            worksheet.column_dimensions['D'].width = 15  # Total Messages
            
            from openpyxl.styles import Alignment
            for row in worksheet.iter_rows():
                for cell in row:
                    cell.alignment = Alignment(wrap_text=True, vertical='top')
        
        print(f"\n✅ Processing completed!")
        print(f"📁 Output saved to: conversation_outputs_by_row.xlsx")
        print(f"📊 Total rows processed: {len(output_data)}")
        print(f"✅ Successful: {len([x for x in output_data if 'error' not in x.get('Conversation_History', '')])}")
        print(f"❌ Errors: {len([x for x in output_data if 'error' in x.get('Conversation_History', '')])}")
        
    except Exception as e:
        print(f"Error loading Excel file: {str(e)}")
        return

if __name__ == "__main__":
    execute_multi_turn_tool_call('D:\\Uni Study\\Sem-6\\6.My Code\\2.Multi_turn\\miss_para_query_dataset.xlsx')
# Out:
# Found 10 rows to process (limited to first 1 rows)
# Processing row 1/10:   0%|          | 0/10 [00:00<?, ?it/s]
# Row 1 - User: Send job offer for Senior Developer position with $95,000 base salary, start date 2024-11-01. Offer expires in 7 days.
# Row 1 - Assistant: <tool_call>[
#   {
#     "id": "a9R6p6SGY",
#     "type": "function",
#     "function": {
#       "name": "send_offer_letter",
#       "arguments": "{\"candidate_id\": \"candidate123\", \"job_title\": \"Senior Developer\", \"salary_base\": 95000, \"start_date\": \"2024-11-01\", \"expiration_days\": 7}"
#     }
#   }
# ]</tool_call>
# Row 1 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 1 - User: The candidate_id is CAND-2024-001.
# Processing row 2/10:  10%|█         | 1/10 [00:01<00:09,  1.03s/it]
# Row 1 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 1 completed - 5 messages in conversation
#
# Row 2 - User: I need to process payment for invoice INV-2024-001 for $15,750 in USD using ACH transfer.
# Row 2 - Assistant: <tool_call>[
#   {
#     "id": "tV5yVBI6R",
#     "type": "function",
#     "function": {
#       "name": "process_invoice_payment",
#       "arguments": "{\"invoice_id\": \"INV-2024-001\", \"vendor_id\": \"VND-2024-001\", \"amount\": 15750, \"currency\": \"USD\", \"payment_method\": \"ACH\"}"
#     }
#   }
# ]</tool_call>
# Row 2 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 2 - User: The vendor_id is VEND001.
# Processing row 3/10:  20%|██        | 2/10 [00:01<00:07,  1.07it/s]
# Row 2 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 2 completed - 5 messages in conversation
#
# Row 3 - User: I need to review an employee's profile. Can you retrieve their complete information including personal details, employment history, and performance metrics?
# Row 3 - Assistant: Sure, I can help with that. Please provide the employee's ID.
# Row 3 - User: The employee_id is EMP456.
# Processing row 4/10:  30%|███       | 3/10 [00:02<00:06,  1.08it/s]
# Row 3 - Assistant: <tool_call>[
#   {
#     "id": "0DquwlGrQ",
#     "type": "function",
#     "function": {
#       "name": "get_employee_profile",
#       "arguments": "{\"employee_id\": \"EMP456\"}"
#     }
#   }
# ]</tool_call>
# Row 3 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 3 completed - 5 messages in conversation
#
# Row 4 - User: I need to update inventory. We sold 15 units today, so please reduce the count by 15 and mark it as a sale. Updated by EMP789.
# Row 4 - Assistant: <tool_call>[
#   {
#     "id": "CpwM6pAjT",
#     "type": "function",
#     "function": {
#       "name": "update_inventory_count",
#       "arguments": "{\"product_id\": \"PROD123\", \"quantity_change\": -15, \"reason\": \"sale\", \"updated_by\": \"EMP789\"}"
#     }
#   }
# ]</tool_call>
# Row 4 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 4 - User: The product_id is PROD789.
# Row 4 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 4 completed - 5 messages in conversation
# Processing row 5/10:  40%|████      | 4/10 [00:03<00:05,  1.13it/s]
# Row 5 - User: Create annual performance review with reviewer CUST789 covering period 2024-01-01 to 2024-12-31. Overall rating is 4 out of 5.
# Row 5 - Assistant: <tool_call>[
#   {
#     "id": "LXzd0joDF",
#     "type": "function",
#     "function": {
#       "name": "create_performance_review",
#       "arguments": "{\"employee_id\": \"CUST789\", \"reviewer_id\": \"CUST789\", \"review_period\": {\"start_date\": \"2024-01-01\", \"end_date\": \"2024-12-31\"}, \"overall_rating\": 4, \"review_type\": \"annual\"}"
#     }
#   }
# ]</tool_call>
# Row 5 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 5 - User: The employee_id is EMP002.
# Processing row 6/10:  50%|█████     | 5/10 [00:04<00:04,  1.06it/s]
# Row 5 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 5 completed - 5 messages in conversation
#
# Row 6 - User: Track a shipment with UPS carrier and include the full tracking history.
# Row 6 - Assistant: <tool_call>[
#   {
#     "id": "oKCAwG7a7",
#     "type": "function",
#     "function": {
#       "name": "track_shipment",
#       "arguments": "{\"tracking_number\": \"1Z12345E6789012345\", \"carrier\": \"UPS\", \"include_history\": true}"
#     }
#   }
# ]</tool_call>
# Row 6 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 6 - User: The tracking_number is 1Z999AA1234567890.
# Processing row 7/10:  60%|██████    | 6/10 [00:05<00:03,  1.12it/s]
# Row 6 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 6 completed - 5 messages in conversation
#
# Row 7 - User: Track performance for Google Ads campaigns, monitoring impressions, clicks, and cost per click metrics. Refresh data every 30 minutes.
# Row 7 - Assistant: <tool_call>[
#   {
#     "id": "vu3M9mEQz",
#     "type": "function",
#     "function": {
#       "name": "track_ad_performance",
#       "arguments": "{\"ad_ids\": [\"1234567890\"], \"platform\": \"google_ads\", \"metrics\": [\"impressions\", \"clicks\", \"cost_per_click\"], \"polling_interval_minutes\": 30}"
#     }
#   }
# ]</tool_call>
# Row 7 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 7 - User: The ad_ids is ['AD-001', 'AD-002'].
# Processing row 8/10:  70%|███████   | 7/10 [00:06<00:02,  1.14it/s]
# Row 7 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 7 completed - 5 messages in conversation
#
# Row 8 - User: Send job offer for Senior Developer position with $95,000 base salary, start date 2024-11-01. Offer expires in 7 days.
# Row 8 - Assistant: <tool_call>[
#   {
#     "id": "W3vsgKTD0",
#     "type": "function",
#     "function": {
#       "name": "send_offer_letter",
#       "arguments": "{\"candidate_id\": \"candidate123\", \"job_title\": \"Senior Developer\", \"salary_base\": 95000, \"start_date\": \"2024-11-01\", \"expiration_days\": 7}"
#     }
#   }
# ]</tool_call>
# Row 8 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 8 - User: The candidate_id is CAND-2024-001.
# Processing row 9/10:  80%|████████  | 8/10 [00:07<00:01,  1.13it/s]
# Row 8 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 8 completed - 5 messages in conversation
#
# Row 9 - User: Track performance for Google Ads campaigns, monitoring impressions, clicks, and cost per click metrics. Refresh data every 30 minutes.
# Row 9 - Assistant: <tool_call>[
#   {
#     "id": "nseDrKIji",
#     "type": "function",
#     "function": {
#       "name": "track_ad_performance",
#       "arguments": "{\"ad_ids\": [\"ad123\", \"ad456\"], \"platform\": \"google_ads\", \"metrics\": [\"impressions\", \"clicks\", \"cost_per_click\"], \"polling_interval_minutes\": 30}"
#     }
#   }
# ]</tool_call>
# Row 9 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 9 - User: The ad_ids is ['AD-001', 'AD-002'].
# Processing row 10/10:  90%|█████████ | 9/10 [00:08<00:00,  1.12it/s]
# Row 9 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 9 completed - 5 messages in conversation
#
# Row 10 - User: I need to update inventory. We sold 15 units today, so please reduce the count by 15 and mark it as a sale. Updated by EMP002.
# Row 10 - Assistant: <tool_call>[
#   {
#     "id": "c51LTdPXO",
#     "type": "function",
#     "function": {
#       "name": "update_inventory_count",
#       "arguments": "{\"product_id\": \"PROD001\", \"quantity_change\": -15, \"reason\": \"sale\", \"updated_by\": \"EMP002\"}"
#     }
#   }
# ]</tool_call>
# Row 10 - Assistant: Error processing message: call_function_and_get_response() takes 2 positional arguments but 3 were given
# Row 10 - User: The product_id is PROD001.
# Processing row 10/10: 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]
# Row 10 - Assistant: Error processing message: 'dict' object has no attribute 'choices'
# Row 10 completed - 5 messages in conversation
# ✅ Processing completed!
# 📁 Output saved to: conversation_outputs_by_row.xlsx
# 📊 Total rows processed: 10
# ✅ Successful: 10
# ❌ Errors: 0

# %% [markdown]
# # Base

# %%
from openai import OpenAI
import json

from tqdm import tqdm
from secret_key import openai_api_key
import pandas as pd
import datetime

client = OpenAI(

    api_key=openai_api_key
)

# Utils
def call_model(messages):
    """Call the model with the provided messages"""
    system_message = {
        "role": "system",
        "content": """
            You are a function-calling AI assistant. Your job is to process user queries, call the appropriate tools, and format responses in natural language.
            For each tool call, return a JSON object within <tool_call> tags.
            After receiving a tool response, provide a human-readable summary of the result.
        """
    }
    try:
        response = client.chat.completions.create(
            model="gpt-5-2025-08-07",
            messages=[system_message] + messages,
            tools=tools,
            #temperature=0,
            parallel_tool_calls=False
        )
        return response
    except Exception as e:
        return {"choices": [{"message": {"content": f"Error calling model: {str(e)}"}}]
                } 

def call_function_and_get_response(function_name, function_arguments):
    """Execute the function and return its response as a tool message"""
    try:
        # Parse the JSON string into a dictionary
        if isinstance(function_arguments, str):
            args = json.loads(function_arguments)
        else:
            args = function_arguments
            
        function_response = globals()[function_name](**args)
        return {
            "role": "tool",
            "content": json.dumps(function_response),
            "tool_call_id": f"call_{function_name}_{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
        }
    except Exception as e:
        return {
            "role": "tool",
            "content": json.dumps({"error": f"Function {function_name} failed: {str(e)}"}),
            "tool_call_id": f"error_{function_name}_{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
        }
    
# Load queries from Excel
def load_queries_from_excel(filename):
    """Load user queries from Excel file"""
    try:
        df = pd.read_excel(filename)
        queries = []
        for query_json in df['Queries (2 queries in JSON format)']:
            queries.extend(json.loads(query_json))
        return queries
    except Exception as e:
        print(f"Error loading Excel file: {str(e)}")
        return []

# Main execution
def execute_multi_turn_tool_call(filename):
    """Execute multi-turn tool calls and save conversation to Excel"""
    # Load Excel file first to get total rows
    try:
        df = pd.read_excel(filename)
        total_conversations = len(df)
        print(f"\nFound {total_conversations} conversations to process")
        
        # Create progress bar
        pbar = tqdm(total=total_conversations, desc="Processing conversations")
        
        user_messages = []
        for idx, row in df.iterrows():
            try:
                queries = json.loads(row['Queries (2 queries in JSON format)'])
                user_messages.extend(queries)
                pbar.update(1)
                pbar.set_description(f"Processing conversation {idx+1}/{total_conversations}")
            except Exception as e:
                print(f"\nError parsing row {idx+1}: {e}")
                pbar.update(1)
                continue
        
        pbar.close()
        
        if not user_messages:
            print("No valid queries found in Excel file.")
            return
            
    except Exception as e:
        print(f"Error loading Excel file: {str(e)}")
        return
    
    messages = []
    conversation = []
    
    while user_messages:
        # Call the model with current messages
        response = call_model(messages)
        
        # Handle response based on type
        if isinstance(response, dict):
            assistant_message = {
                "role": "assistant",
                "content": response.get("choices", [{"message": {"content": "Error processing request"}}])[0]["message"]["content"]
            }
        else:
            assistant_message = response.choices[0].message.to_dict()  # Convert to dict for consistent access
        
        messages.append(assistant_message)
        conversation.append({
            "role": assistant_message["role"],
            "content": assistant_message["content"] or json.dumps(assistant_message.get("tool_calls", []))
        })
        
        if assistant_message["content"]:
            # If assistant responds with content, print and add to conversation
            print(f"Assistant: {assistant_message['content']}")
        elif assistant_message.get("tool_calls"):
            # If assistant makes a tool call, process it
            for tool_call in assistant_message["tool_calls"]:
                # Fix: Access dictionary keys properly
                function_name = tool_call["function"]["name"]
                function_arguments = json.loads(tool_call["function"]["arguments"])  # Parse JSON string to dict
                tool_call_json = {
                    "name": function_name,
                    "arguments": tool_call["function"]["arguments"]
                }
                tool_call_message = f"<tool_call>{json.dumps(tool_call_json)}</tool_call>"
                print(f"Assistant: {tool_call_message}")
                conversation[-1]["content"] = tool_call_message
                
                # Execute the function and get response with parsed arguments
                tool_response = {
                    "role": "tool",
                    "content": json.dumps(globals()[function_name](**function_arguments)),  # Use parsed arguments
                    "tool_call_id": tool_call["id"]
                }
                
                print(f"Function response: {tool_response['content']}")
                messages.append(tool_response)
                conversation.append({
                    "role": "tool",
                    "content": tool_response['content']
                })
            
            # Get assistant's final response after all function calls
            final_response = call_model(messages)
            if isinstance(final_response, dict):
                final_message = {
                    "role": "assistant",
                    "content": final_response.get("choices", [{"message": {"content": "Error processing request"}}])[0]["message"]["content"]
                }
            else:
                final_message = final_response.choices[0].message.to_dict()
            
            print(f"Assistant: {final_message['content']}")
            messages.append(final_message)
            conversation.append({
                "role": "assistant",
                "content": final_message['content']
            })
        
        # Fetch next user message if available
        if user_messages:
            user_message = user_messages.pop(0)
            print(f"User: {user_message['content']}")
            messages.append(user_message)
            conversation.append(user_message)
        else:
            break
    
    # Save conversation to Excel
    excel_data = [{"Conversation": json.dumps(conversation, indent=2)}]
    df = pd.DataFrame(excel_data)
    

    with pd.ExcelWriter('conversation_output.xlsx', engine='openpyxl') as writer:
        df.to_excel(writer, index=False, sheet_name='Conversation')
        worksheet = writer.sheets['Conversation']
        worksheet.column_dimensions['A'].width = 100
        from openpyxl.styles import Alignment
        for row in worksheet.iter_rows():
            for cell in row:
                cell.alignment = Alignment(wrap_text=True, vertical='top')
    
    print("Conversation saved to conversation_output.xlsx")
    
if __name__ == "__main__":
    execute_multi_turn_tool_call('D:\\Uni Study\\Sem-6\\6.My Code\\2.Multi_turn\\base_query_dataset.xlsx')
# Out:
# Found 100 conversations to process
# Processing conversation 100/100: 100%|██████████| 100/100 [00:00<00:00, 636.96it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 213
#     210     print("Conversation saved to conversation_output.xlsx")
#     212 if __name__ == "__main__":
# --> 213     execute_multi_turn_tool_call('D:\\Uni Study\\Sem-6\\6.My Code\\2.Multi_turn\\base_query_dataset.xlsx')
#
# Cell In[4], line 122, in execute_multi_turn_tool_call(filename)
#     118 conversation = []
#     120 while user_messages:
#     121     # Call the model with current messages
# --> 122     response = call_model(messages)
#     124     # Handle response based on type
#     125     if isinstance(response, dict):
#
# Cell In[4], line 36, in call_model(messages)
#      17 system_message = {
#      18     "role": "system",
#      19     "content": """You are an AI assistant with access to a set of tools. Your goal is to accurately and helpfully respond to user queries.
#    (...)
#      33             """
#      34 }
#      35 try:
# ---> 36     response = client.chat.completions.create(
#      37         model="gpt-5-2025-08-07",
#      38         messages=[system_message] + messages,
#      39         tools=tools,
#      40         #temperature=0,
#      41         parallel_tool_calls=False
#      42     )
#      43     return response
#      44 except Exception as e:
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\resources\chat\completions\completions.py:1131, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1086 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1087 def create(
#    1088     self,
#    (...)
#    1128     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1129 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1130     validate_response_format(response_format)
# -> 1131     return self._post(
#    1132         "/chat/completions",
#    1133         body=maybe_transform(
#    1134             {
#    1135                 "messages": messages,
#    1136                 "model": model,
#    1137                 "audio": audio,
#    1138                 "frequency_penalty": frequency_penalty,
#    1139                 "function_call": function_call,
#    1140                 "functions": functions,
#    1141                 "logit_bias": logit_bias,
#    1142                 "logprobs": logprobs,
#    1143                 "max_completion_tokens": max_completion_tokens,
#    1144                 "max_tokens": max_tokens,
#    1145                 "metadata": metadata,
#    1146                 "modalities": modalities,
#    1147                 "n": n,
#    1148                 "parallel_tool_calls": parallel_tool_calls,
#    1149                 "prediction": prediction,
#    1150                 "presence_penalty": presence_penalty,
#    1151                 "prompt_cache_key": prompt_cache_key,
#    1152                 "reasoning_effort": reasoning_effort,
#    1153                 "response_format": response_format,
#    1154                 "safety_identifier": safety_identifier,
#    1155                 "seed": seed,
#    1156                 "service_tier": service_tier,
#    1157                 "stop": stop,
#    1158                 "store": store,
#    1159                 "stream": stream,
#    1160                 "stream_options": stream_options,
#    1161                 "temperature": temperature,
#    1162                 "tool_choice": tool_choice,
#    1163                 "tools": tools,
#    1164                 "top_logprobs": top_logprobs,
#    1165                 "top_p": top_p,
#    1166                 "user": user,
#    1167                 "web_search_options": web_search_options,
#    1168             },
#    1169             completion_create_params.CompletionCreateParamsStreaming
#    1170             if stream
#    1171             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1172         ),
#    1173         options=make_request_options(
#    1174             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1175         ),
#    1176         cast_to=ChatCompletion,
#    1177         stream=stream or False,
#    1178         stream_cls=Stream[ChatCompletionChunk],
#    1179     )
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:979, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     977 response = None
#     978 try:
# --> 979     response = self._client.send(
#     980         request,
#     981         stream=stream or self._should_stream_response_body(request=request),
#     982         **kwargs,
#     983     )
#     984 except httpx.TimeoutException as err:
#     985     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File c:\Users\KUNJAN SHAH\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
